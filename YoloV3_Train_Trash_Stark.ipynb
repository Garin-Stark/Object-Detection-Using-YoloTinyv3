# %%
# !nvidia-smi
# Out:
# Mon Jan 17 16:42:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# '20000batch YOLO'  'Colab Notebooks'  'My Drive'   yolov3Tiny   yolov3-tiny_v2

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15395, done.
# remote: Total 15395 (delta 0), reused 0 (delta 0), pack-reused 15395
# Receiving objects: 100% (15395/15395), 14.02 MiB | 23.53 MiB/s, done.
# Resolving deltas: 100% (10353/10353), done.

# %%
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %%
# !cp cfg/yolov3-tiny.cfg cfg/yolov3_training.cfg
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 30000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=3@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=3@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=3@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=24@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=24@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=24@' cfg/yolov3_training.cfg

# %%
# !echo -e 'botol\nkertas\nmetal' > data/obj.names
# !echo -e 'classes= 3\ntrain= data/train.txt\nvalid= data/test.txt\nnames= data/obj.names\nbackup= /mydrive/yolov3Tiny' > data/obj.data

# %%
# !cp cfg/yolov3_training.cfg /mydrive/yolov3Tiny/yolov3_testing.cfg

# %%
# !cp data/obj.names /mydrive/yolov3-tiny_v2/classes.txt

# %%
# !mkdir data/obj

# %%
# !unzip /mydrive/yolov3-tiny_v2/data.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov3-tiny_v2/data.zip
#   inflating: data/obj/data/botol1.PNG
#   inflating: data/obj/data/botol1.txt
#   inflating: data/obj/data/botol10.jpg
#   inflating: data/obj/data/botol10.txt
#   inflating: data/obj/data/botol11.jpg
#   inflating: data/obj/data/botol11.txt
#   inflating: data/obj/data/botol12.jpg
#   inflating: data/obj/data/botol12.txt
#   inflating: data/obj/data/botol13.jpg
#   inflating: data/obj/data/botol13.txt
#   inflating: data/obj/data/botol14.jpg
#   inflating: data/obj/data/botol14.txt
#   inflating: data/obj/data/botol15.jpg
#   inflating: data/obj/data/botol15.txt
#   inflating: data/obj/data/botol16.jpg
#   inflating: data/obj/data/botol16.txt
#   inflating: data/obj/data/botol18.jpg
#   inflating: data/obj/data/botol18.txt
#   inflating: data/obj/data/botol19.jpg
#   inflating: data/obj/data/botol19.txt
#   inflating: data/obj/data/botol2.jpg
#   inflating: data/obj/data/botol2.txt
#   inflating: data/obj/data/botol20.jpg
# ...

# %%
import glob
images_list = glob.glob("data/obj/data/*.jpg")
with open("data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-01-17 16:57:20--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  46.7MB/s    in 3.6s
#
# 2022-01-17 16:57:24 (42.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
#!./darknet detector train data/obj.data cfg/yolov3_training.cfg /mydrive/yolov3Tiny/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 281134, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.827267), count: 4, class_loss = 0.073737, iou_loss = 0.112114, total_loss = 0.185851
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 23 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 281138, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 16 Avg (IOU: 0.657886), count: 4, class_loss = 1.496116, iou_loss = 0.401928, total_loss = 1.898044
# ...
